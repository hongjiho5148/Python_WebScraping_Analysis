# %% [markdown]
# #### 2-1. Nate 뉴스기사 제목 스크래핑하기

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from IPython.display import Image, display

section_dict = {'최신뉴스':'n0100','정치':'n0200','경제':'n0300','사회':'n0400',\
                '세계':'n0500','IT/과학':'n0600'}
print(section_dict)

def print_news(section_name):    
    m_id = section_dict[section_name]

    url = f'https://news.nate.com/recent?mid={m_id}'
    print(url)

    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }

    res = requests.get(url, headers=req_header)
    print(type(res))
    print(res.status_code)

    if res.ok:
        res.encoding = 'euc-kr'
        html = res.text
        soup = BeautifulSoup(html, 'html.parser')

        print(f'======> {url} {section_name} 뉴스 <======')   

        tags = soup.select("div.postListType.noListTitle div.mlt01")
        print(len(tags))

        for idx,div_tag in enumerate(tags,1): 
            print(f'============>> {idx}')       
            a_tag = div_tag.find('a')
            a_join_url = urljoin(url,a_tag['href'])
            print(a_join_url)

            img_tag = div_tag.select_one('span.ib img')
            if img_tag:
                photo_url = urljoin(url,img_tag['src'])
                print(photo_url)
                display(Image(url=photo_url))

            h2_tag = div_tag.select_one('span.tb h2.tit')
            title = h2_tag.text
            print(title)

    else:
        print(f'에러코드 = {res.status_code}')

print_news('IT/과학')
# Out:
# {'최신뉴스': 'n0100', '정치': 'n0200', '경제': 'n0300', '사회': 'n0400', '세계': 'n0500', 'IT/과학': 'n0600'}
# https://news.nate.com/recent?mid=n0600
# <class 'requests.models.Response'>
# 200
# ======> https://news.nate.com/recent?mid=n0600 IT/과학 뉴스 <======
# 20
# ============>> 1
# https://news.nate.com/view/20260209n33631?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ns/2026/02/09/NISI20250204_0001762652_web.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ns/2026/02/09/NISI20250204_0001762652_web.jpg"/>
# 크래프톤 김창한 "구글 AI '지니3', 단기간 내 게임 대체 어렵다"
# ============>> 2
# https://news.nate.com/view/20260209n32800?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cz/2026/02/09/cz_1770626837541_439314_0.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cz/2026/02/09/cz_1770626837541_439314_0.jpg"/>
# 크래프톤, 매출 '3조 클럽' 입성…영업이익은 10% 감소
# ============>> 3
# https://news.nate.com/view/20260209n33508?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/in/2026/02/09/221db393d7ea82.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/in/2026/02/09/221db393d7ea82.jpg"/>
# KT, 사외이사 4석 교체 절차 착수…국민연금 변수 부상
# ============>> 4
# https://news.nate.com/view/20260209n33091?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/hn/2026/02/09/20260209503401.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/hn/2026/02/09/20260209503401.jpg"/>
# 카카오, 또 근로기준법 무더기 위반…노조 "4년 새 노동 환경 후퇴"
# ============>> 5
# https://news.nate.com/view/20260209n33452?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ed/2026/02/09/PS26020901424.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ed/2026/02/09/PS26020901424.jpg"/>
# 1030 업고 '앱 속의 앱' 키우는 토스··'쉬운 창업' 판 깔았다
# ============>> 6
# https://news.nate.com/view/20260209n33390?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/aj/2026/02/09/20260209174128329863.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/aj/2026/02/09/20260209174128329863.jpg"/>
# 카카오맵, 수도권 주요 농수산물시장 실내지도 서비스 오픈
# ============>> 7
# https://news.nate.com/view/20260209n33355?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ee/2026/02/09/20260209173811409774.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ee/2026/02/09/20260209173811409774.jpg"/>
# KT, 박윤영 체제 앞두고 거버넌스 재편…3월 주총 앞두고 이사진 4명 물갈이
# ============>> 8
# https://news.nate.com/view/20260209n33351?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ed/2026/02/09/PS26020901417.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ed/2026/02/09/PS26020901417.jpg"/>
# 인크로스, 4분기 영업이익 36억원…전년 대비 9.7% 증가
# ============>> 9
# https://news.nate.com/view/20260209n33310?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/aj/2026/02/09/20260209173531364253.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/aj/2026/02/09/20260209173531364253.jpg"/>
# KT, 사외이사 교체 논의 착수…CEO 견제 구조 시험대
# ============>> 10
# https://news.nate.com/view/20260209n33308?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cz/2026/02/09/cz_1770626405003_980328_0.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cz/2026/02/09/cz_1770626405003_980328_0.jpg"/>
# 'AI닷컴' 도메인 1000억원에 팔려…역대 최고액
# ============>> 11
# https://news.nate.com/view/20260209n33291?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/mk/2026/02/09/20260210_01110128000001_S00.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/mk/2026/02/09/20260210_01110128000001_S00.jpg"/>
# "폭발위험 적은 액체원자로, AI시대 해결사"
# ============>> 12
# https://news.nate.com/view/20260209n33149?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cz/2026/02/09/cz_1770626164372_794517_0.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cz/2026/02/09/cz_1770626164372_794517_0.jpg"/>
# '소프트웨어 종말론' 공포에 1조달러 증발…"AI가 SaaS 대체" VS "과장" 갑론을박
# ============>> 13
# https://news.nate.com/view/20260209n33037?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/yt/2026/02/09/PYH2026020918740001300_P2.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/yt/2026/02/09/PYH2026020918740001300_P2.jpg"/>
# 인사말 하는 김용선 지식재산처장
# ============>> 14
# https://news.nate.com/view/20260209n25692?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ae/2026/02/09/ae_1770625984431_129850_0.png
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ae/2026/02/09/ae_1770625984431_129850_0.png"/>
# 색 하나 바꿨을 뿐인데…"명품 같잖아?" 아이폰 불티나게 팔리는 中
# ============>> 15
# https://news.nate.com/view/20260209n32995?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ed/2026/02/09/PS26020901405.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ed/2026/02/09/PS26020901405.jpg"/>
# '챗봇에서 실무형 AI로'…공공 AX 패러다임 바뀐다
# ============>> 16
# https://news.nate.com/view/20260209n32982?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cb/2026/02/09/202602091717492818_0.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/cb/2026/02/09/202602091717492818_0.jpg"/>
# 크래프톤, '배그 흥행' 작년 매출 3조 '최대'…투자 확대로 수익은 감소
# ============>> 17
# https://news.nate.com/view/20260209n32810?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ns/2026/02/09/NISI20260209_0002059452_web.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ns/2026/02/09/NISI20260209_0002059452_web.jpg"/>
# [컨콜]크래프톤 "15개 신작 개발 착수…파이프라인 확장할 것"
# ============>> 18
# https://news.nate.com/view/20260209n32569?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/mt/2026/02/09/2026020916571884142_1.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/mt/2026/02/09/2026020916571884142_1.jpg"/>
# [컨콜] 크래프톤 "지니3, 단기간에 게임 완전히 대체하지 않을 것"
# ============>> 19
# https://news.nate.com/view/20260209n32484?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/sw/2026/02/09/20260209516834.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/sw/2026/02/09/20260209516834.jpg"/>
# 크래프톤, 3년간 1조원 이상 주주환원 추진
# ============>> 20
# https://news.nate.com/view/20260209n32447?mid=n0600
# https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ns/2026/02/09/NISI20260209_0002059646_web.jpg
# <img src="https://thumbnews.nateimg.co.kr/news90///news.nateimg.co.kr/orgImg/ns/2026/02/09/NISI20260209_0002059646_web.jpg"/>
# 위메이드맥스, 작년 영업손실 487억…매출은 98.5%↑
