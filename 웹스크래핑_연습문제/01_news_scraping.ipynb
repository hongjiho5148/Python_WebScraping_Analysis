# %% [markdown]
# ### 질문1

# %%
import requests
from bs4 import BeautifulSoup

req_param = {"sid": "economy"}
url = "https://news.daum.net/{sid}".format(**req_param)
req_header = {
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "referer": "https://news.daum.net/",
}

res = requests.get(url, headers=req_header)
res.encoding = "utf-8"
print(url)
print(type(res))
print(res.status_code)

if res.ok:
    soup = BeautifulSoup(res.text, "html.parser")

    items = soup.select("a.item_newsheadline2")
    print(type(items), len(items))  

    for item in items:
        
        title_tag = item.select_one(".tit_txt")
        if title_tag:
            title = title_tag.text.strip()
            link = item["href"]

            print(link)
            print(title)
else:
    # 응답(response)이 error이면 status_code 출력
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.daum.net/economy
# <class 'requests.models.Response'>
# 200
# <class 'bs4.element.ResultSet'> 9
# https://v.daum.net/v/20260208093045400
# '기어이 중국이 해냈다'…MIT가 폭로한 '무서운 진실' [김리안의 에네르기파WAR]
# https://v.daum.net/v/20260208093000379
# 반도체 훈풍에…4년만에 초과세수 기대
# https://v.daum.net/v/20260208092700332
# 작년 민간아파트 분양 10년 새 최소…공급 빙하에 청년 주거비↑
# https://v.daum.net/v/20260208092145245
# 올해 설 성수품 가격은…한우·조기 비싸고 사과·배 안정세”
# https://v.daum.net/v/20260208091004093
# [정부 주요 일정] 경제·사회부처 주간 일정 (2월 9일 ~ 2월 13일)
# https://v.daum.net/v/20260208090634050
# AI 자본투자 거품론, 제2 닷컴 버블 우려 속 수익창출 여부가 관건
# https://v.daum.net/v/20260208090629048
# 다다와 초현실주의, 전쟁은 일상과 더불어 예술도 붕괴시킨다
# https://v.daum.net/v/20260208090621040
# 미국 패권의 후퇴, 다극세계권의 약진
# https://v.daum.net/v/20260208070311633
# “돈으로 행복과 사랑 살 수 없다”는 말의 맹점

# %% [markdown]
# ### 문제2

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {
    '기후/환경':'climate', '사회':'society', '경제':'economy', '정치':'politics',
    '국제':'world', '문화':'culture', '생활':'life', 'IT/과학':'tech', '인물':'people'
}

def print_news(section_name):  
    sid = section_dict.get(section_name, 'economy')
    
    url = f'https://news.daum.net/{sid}'
    
    req_header = {
        'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
    }

    res = requests.get(url, headers=req_header)
    res.encoding = 'utf-8'

    if res.ok:
        print(f"======> {url} {section_name} 뉴스 <======")
        
        soup = BeautifulSoup(res.text, 'html.parser')
        
        items = soup.select("a.item_newsheadline2")
        
        for item in items:
            title_tag = item.select_one(".tit_txt")
            if title_tag:
                title = title_tag.text.strip()
                link = item['href']
                
                print(link)
                print(f'"{title}"')
    else:
        # 응답(response)이 error이면 status_code 출력
        print(f'Error Code = {res.status_code}')

# 함수 실행 예시
print_news('문화')
# Out:
# ======> https://news.daum.net/culture 문화 뉴스 <======
# https://v.daum.net/v/20260208100410045
# "“이 말 앞에서 발걸음이 멈췄다…양평에서 벌어진 일”"
# https://v.daum.net/v/20260208100235998
# "김이 모락모락 피어오르는 해수 온천 위로 떠오르는 태양 [전승훈 기자의 아트로드]"
# https://v.daum.net/v/20260208100141948
# "덕운스님 "펫로스는 극복이 아니라, 아픔에 익숙해지는 과정"[문화人터뷰]"
# https://v.daum.net/v/20260208100005889
# "용한 철학관 가는 대신 “챗GPT에게 물어보살”"
# https://v.daum.net/v/20260208094929710
# "[초점]간판 차은우·김선호 휘청…위기의 판타지오"
# https://v.daum.net/v/20260208094236584
# "‘책만 팔아선 생존 못한다’…사업 확장하는 서점들"
# https://v.daum.net/v/20260208093300439
# "“마지막 탈출 기회” 이 대통령 최후통첩에…‘다주택’ 스타들의 선택은? [스테크]"
# https://v.daum.net/v/20260208093142418
# "미래 묻고 속마음 터놓고 위안 얻는다…신의 영역도 AI가 대체할까"
# https://v.daum.net/v/20260208090452995
# "〈검정고무신〉 소송 이후, 재판은 이겼지만 신뢰는 무너졌다 [콘텐츠의 순간들]"
