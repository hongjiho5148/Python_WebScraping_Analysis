# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-libmamba-solver, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, PyGithub, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.13.5
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve, typing-extensions
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4

# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.5
# bs4 버전 = 4.13.5

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
#url = 'https://news.naver.com/section/105'

# dict타입으로 요청 파라미터 설정
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res  = requests.get(url, headers=req_header)
print(res.status_code)
print(res.ok)
print(type(res))
print(res.text)
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
# BeautifulSoup 객체 생성  
if res.ok:
    soup = BeautifulSoup(res.text,'html.parser')
    #print(len(soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")))
    # CSS 선택자를 사용해서 a tag 목록 가져오기
    a_tags = soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")
    for a_tag in a_tags:
        title = (a_tag.text.strip())
        link = a_tag['href']
        print(title)
        print(link)

else:
    print(f'Error Code = {res.status_code}')
    

# <a> 태그 리스트 순회하기    

# 응답(response)이 Error 이면 status code 출력
# Out:
# https://news.naver.com/section/105
# 200
# True
# <class 'requests.models.Response'>
# <!doctype html>
# <html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="referrer" contents="always">
# 		<meta http-equiv="refresh" content="600">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="IT/과학 : 네이버 뉴스">
# 		<meta property="og:type" content="website">
# 		<meta property="og:url" content="https://news.naver.com/section/105">
# 		<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta property="og:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">
# 		<meta property="og:article:author" content="네이버">
# 		<meta name="twitter:card" content="summary">
# 		<meta name="twitter:title" content="IT/과학 : 네이버 뉴스">
# 		<meta name="twitter:site" content="네이버 뉴스">
# 		<meta name="twitter:creator" content="네이버 뉴스">
# 		<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# 		<meta name="twitter:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">
# 		<title>IT/과학 : 네이버 뉴스</title>
# 			<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20260205/news.css">
# 			<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />
# 			<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 			<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />
# 			<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />
# 			<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />
# 			<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 					<script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# 		<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# 				<script>
# 			var g_ssc = nsc = "news.v3_sec";
# 			var g_default_area = "itn";
#
# 			var svr = "one-service-r-20260205-260205-154722-ddcf4bf67-f7rvs";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (window.abt && window.abt["variantName"]) {
# 						customParam.abt = (window.abt["feature"] === "feed") ? "news-FEED" : "news";
# 					}
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "105";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			var abt = {
# 				"experimentId": "",
# 				"variantName": "",
# 				"feature": ""
# 			};
# 		</script>
# 		<script src="https://static-nnews.pstatic.net/js/min/20260205/common.min.js"></script>
# 	</head>
# 	<body class="n_news_mnews fs1 as_mp_layout as_section_home">
# 		<div class="end_container">
# 		<div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# 		<header role="banner" class="as_gnb_mnews as_type_section">
# 	<div class="header_inner">
# 		<div class="Ngnb">
# 			<div class="Ngnb_inner">
# 				<div class="Ngnb_both">
# 					<div class="Ngnb_left">
# 						<span class="Ngnb_logo"><a href="https://m.naver.com/" class="Nlogo_link _LINK" data-clk="gnb.naver" data-url="https://m.naver.com/" data-pc-url="https://www.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# 						<div class="Ngnb_service">
# 							<h1 class="Nservice_item"><a href="https://m.news.naver.com" class="_LINK" data-clk="gnb.news" data-url="https://m.news.naver.com" data-pc-url="https://news.naver.com/"><span class="Nicon_service">뉴스</span></a></h1>
# 							<span class="Nservice_subitem">
# 								<a href="https://m.entertain.naver.com" class="_LINK" data-clk="gnb.entertain" data-url="https://m.entertain.naver.com" data-pc-url="https://entertain.naver.com/home">
# 									<span class="Nicon_family Nicon_entertain">엔터</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://m.sports.naver.com" class="_LINK" data-clk="gnb.sports" data-url="https://m.sports.naver.com" data-pc-url="https://sports.news.naver.com/index">
# 									<span class="Nicon_family Nicon_sports">스포츠</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://weather.naver.com" data-clk="gnb.weather">
# 									<span class="Nicon_family Nicon_weather">날씨</span>
# 								</a>
# 							</span>
# 							<span class="Nservice_subitem">
# 								<a href="https://contents.premium.naver.com" data-clk="gnb.premium">
# 									<span class="Nicon_family Nicon_premium">프리미엄</span>
# 								</a>
# 							</span>
# 						</div>
# 					</div>
# 					<div class="Ngnb_right">
# 						<div class="Ngnb_group">
# 							<div id="gnb" class="gnb_dark_type2"></div>
# 						</div>
# 						<div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# 						<div class="Ngnb_tool">
# 							<a href="javascript:;" class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho"><span class="Nicon_search">검색</span></a>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="_LNB_PARENT_WRAP" class="Nlnb" style="z-index:3000;" data-scroll-fixed="true">
# 		<div id="_LNB_WRAP" class="Nlnb_menu Ntype_scroll ">
# 			<div id="_LNB" class="Nlnb_menu_inner">
# 				<ul class="Nlnb_menu_list" role="tablist">
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.press"><span class="Nitem_link_menu">언론사별</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/100" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.pol"><span class="Nitem_link_menu">정치</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/101" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.eco"><span class="Nitem_link_menu">경제</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/102" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.soc"><span class="Nitem_link_menu">사회</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/103" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.lif"><span class="Nitem_link_menu">생활/문화</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# 						<a href="https://news.naver.com/section/105" class="Nitem_link" role="tab" aria-selected="true" data-clk="lnb.it"><span class="Nitem_link_menu">IT/과학</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/section/104" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.wor"><span class="Nitem_link_menu">세계</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/ranking/popularDay.naver?mid&#x3D;etc&amp;sid1&#x3D;111" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.rank"><span class="Nitem_link_menu">랭킹</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/newspaper/home" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.paper"><span class="Nitem_link_menu">신문보기</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/opinion/home.naver" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.opi"><span class="Nitem_link_menu">오피니언</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/tv/index.naver?mid&#x3D;tvh" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.tv"><span class="Nitem_link_menu">TV</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/main/factcheck/main.naver" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.fact"><span class="Nitem_link_menu">팩트체크</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://media.naver.com/algorithm" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.algo"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# 					</li>
# 					<li class="Nlist_item _LNB_ITEM" role="presentation">
# 						<a href="https://news.naver.com/ombudsman/errorArticleList" class="Nitem_link" role="tab" aria-selected="false" data-clk="lnb.correct"><span class="Nitem_link_menu">정정보도 모음</span></a>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 		</div>
# 	</div>
# </header>
# <hr>
# <script>
# 	var svt = "20260206105355.454";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
#
# 	var isDegradeMode = false;
# 	var isDegradeN2Mode = false;
# </script>
# <div id="ct_wrap" class="ct_wrap">
# 	<div class="ct_lnb">
# 		<div class="ct_lnb_inner">
# 			<strong class="ct_lnb_date">02.06(금)</strong>
# 			<ul class="ct_lnb_side">
# 				<li class="ct_lnb_side_item">
# 					<a href="https://news.naver.com/main/officeList.naver" class="ct_lnb_side_link" data-clk="slb.allmedia">전체 언론사</a>
# 				</li>
# 				<li class="ct_lnb_side_item">
# 					<a href="https://newsstand.naver.com/" class="ct_lnb_side_link" target="_blank" data-clk="slb.newsstand">뉴스스탠드</a>
# 				</li>
# 				<li class="ct_lnb_side_item">
# 					<a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="ct_lnb_side_link" target="_blank" data-clk="slb.library">라이브러리</a>
# 				</li>
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="ct_scroll_wrapper">
# 		<div class="column0">
# 			<div class="ct_snb">
# 				<h2 class="ct_snb_h2">
# 					<a href="/section/105" class="ct_snb_h2_a" data-clk="lmn_itn.home">IT/과학</a>
# 				</h2>
# 				<ul class="ct_snb_nav">
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/731" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="1">모바일</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/226" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="2">인터넷/SNS</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/227" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="3">통신/뉴미디어</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/230" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="4">IT 일반</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/732" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="5">보안/해킹</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/283" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="6">컴퓨터</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/229" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="7">게임/리뷰</a>
# 					</li>
# 					<li class="ct_snb_nav_item">
# 						<a href="/breakingnews/section/105/228" class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="8">과학 일반</a>
# 					</li>
# 				</ul>
# 				<div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# 					<a href="https://media.naver.com/algorithm" data-clk="lmn_itn.pmb" data-rank="1">
# 						<img data-src="https://ssl.pstatic.net/static.news/image/news/m/2025/01/20/section_home_banner_left_1.png" width="71" height="74" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" alt="AI 뉴스 알고리즘 추천 알고리즘 궁금하다면? 바로가기" style="display: none;">
# 					</a>
# 				</div>
# 				<div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# 					<a href="https://contents.premium.naver.com/" data-clk="lmn_itn.pmb" data-rank="2">
# 						<img data-src="https://ssl.pstatic.net/static.news/image/news/m/2025/01/20/section_home_banner_left_2.png" width="71" height="74" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" alt="프리미엄콘텐츠 투자 정보부터 트렌드까지! 바로가기" style="display: none;">
# 					</a>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="newsct" class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" role="main"><div class="section_component as_section_headline _PERSIST_CONTENT" data-persist="2_sectionHeadline">
# <div class="section_article as_headline _TEMPLATE" data-template-id="SECTION_HEADLINE">
# 	<div class="sa_head">
# 		<span class="sa_head_inner">
# 			<a href="#" class="sa_head_link _TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_9ktjb" data-clk="guide">헤드라인 뉴스 <i class="sa_head_icon">안내</i></a>
# 		</span>
# 		<div id="_SECTION_HEADLINE_INFO_9ktjb" class="sa_head_layer is_hidden">
# 			<p class="sa_head_layer_p">각 헤드라인의 기사와 배열 순서는 개인화를 반영해 추천되며, 기사묶음의 대표 기사는 구독 언론사 중심으로 제공됩니다. 기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 자동 추출됩니다.</p>
# 			<a href="https://media.naver.com/algorithm" class="sa_head_layer_go">알고리즘 자세히 보기</a>
# 			<div class="sa_head_layer_close">
# 				<button type="button" class="_TOGGLE" data-classValue="is_hidden" data-target="_SECTION_HEADLINE_INFO_9ktjb">닫기</button>
# 			</div>
# 		</div>
# 	</div>
# 	<ul id="_SECTION_HEADLINE_LIST_9ktjb" class="sa_list">
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/011/0004587151" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="88000108_000000000000000004587151" data-imp-url="https://n.news.naver.com/mnews/article/011/0004587151" data-imp-index="1">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/011/2026/02/05/4587151.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/011/0004587151" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="88000108_000000000000000004587151" data-imp-url="https://n.news.naver.com/mnews/article/011/0004587151" data-imp-index="1">
# 							<strong class="sa_text_strong">실적 새 역사 쓴 넷마블…‘다장르 신작’ 전략 통했다</strong>
# 						</a>
# 						<div class="sa_text_lede">넷마블이 신작 3종 흥행에 힘입어 지난해 역대 최대 실적을 갈아치웠다. 올해 ‘일곱 개의 대죄: 오리진’ 등을 비롯한 인기 지식재산권(IP) 기반의 차기작이 예정돼 있어 국내 게임업계 ‘빅3’ 자리 굳히기에 들어갔다</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">서울경제</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/011/0004587151" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news011,0004587151" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602051600_00000005/section/105?oid&#x3D;011&amp;aid&#x3D;0004587151" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">42</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/014/0005474274" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="880000FF_000000000000000005474274" data-imp-url="https://n.news.naver.com/mnews/article/014/0005474274" data-imp-index="2">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/014/2026/02/05/5474274.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/014/0005474274" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000FF_000000000000000005474274" data-imp-url="https://n.news.naver.com/mnews/article/014/0005474274" data-imp-index="2">
# 							<strong class="sa_text_strong">AI로 해킹 파장 줄인 통신사… 데이터센터 등 수익성 높인다</strong>
# 						</a>
# 						<div class="sa_text_lede">통신업계를 덮친 해킹 사고 여파에도 SK텔레콤과 LG유플러스가 미래 먹거리로 점찍은 인공지능(AI) 사업에서 실질적 성과를 내며 실적을 방어했다. 올해부터 AI 사업 실적 기여도가 본격적으로 확대되면서 수익성 개선에</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">파이낸셜뉴스</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/014/0005474274" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news014,0005474274" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602050900_00000035/section/105?oid&#x3D;014&amp;aid&#x3D;0005474274" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">38</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/138/0002217304" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="880000AC_000000000000000002217304" data-imp-url="https://n.news.naver.com/mnews/article/138/0002217304" data-imp-index="3">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/138/2026/02/06/2217304.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/138/0002217304" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000AC_000000000000000002217304" data-imp-url="https://n.news.naver.com/mnews/article/138/0002217304" data-imp-index="3">
# 							<strong class="sa_text_strong">오픈AI, 차세대 에이전트형 코딩 모델 ‘GPT-5.3-코덱스’ 공개</strong>
# 						</a>
# 						<div class="sa_text_lede">오픈AI(OpenAI)가 지금까지 공개한 모델 중 가장 강력한 에이전트형 코딩 모델 ‘GPT-5.3-코덱스(GPT-5.3-Codex)’를 출시했다. GPT-5.3-코덱스는 이전 버전인 GPT-5.2-코덱스의 프런티어</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">디지털데일리</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/138/0002217304" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002217304" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602060920_00000037/section/105?oid&#x3D;138&amp;aid&#x3D;0002217304" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">8</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/469/0000912947" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="88156f75_000000000000000000912947" data-imp-url="https://n.news.naver.com/mnews/article/469/0000912947" data-imp-index="4">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/469/2026/02/05/912947.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/469/0000912947" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="88156f75_000000000000000000912947" data-imp-url="https://n.news.naver.com/mnews/article/469/0000912947" data-imp-index="4">
# 							<strong class="sa_text_strong">천하람 &quot;술에 취해 여학우 성희롱, 일어날 수 있는 일&quot; 과거 글 논란</strong>
# 						</a>
# 						<div class="sa_text_lede">천하람 개혁신당 원내대표가 과거 &quot;술에 취한 상태에서 여학우를 성희롱하는 일은 모든 학교에서 일어날 수 있는 일&quot; 등 왜곡된 성인식을 드러내는 온라인 게시글을 올린 사실이 드러나 논란이다. 천 원내대표는 2004년</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">한국일보</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/469/0000912947" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news469,0000912947" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602050740_00000317/section/105?oid&#x3D;469&amp;aid&#x3D;0000912947" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">57</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/014/0005474452" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="880000FF_000000000000000005474452" data-imp-url="https://n.news.naver.com/mnews/article/014/0005474452" data-imp-index="5">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/014/2026/02/06/5474452.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/014/0005474452" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000FF_000000000000000005474452" data-imp-url="https://n.news.naver.com/mnews/article/014/0005474452" data-imp-index="5">
# 							<strong class="sa_text_strong">네이버, &#x27;N배송&#x27; 3년내 50% 이상 확대...멤버십 목표도 20%↑[컨콜]</strong>
# 						</a>
# 						<div class="sa_text_lede">최수연 네이버 대표는 6일 진행된 지난해 4·4분기 실적 발표 컨퍼런스 콜을 통해 &quot;N배송 커버리지를 올해 25%, 내년 35%까지 확대해 3년 내 50% 이상을 목표로 하고 있다&quot;며 &quot;중장기적으로 배송이 네이버 쇼</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">파이낸셜뉴스</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/014/0005474452" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news014,0005474452" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602060950_00000034/section/105?oid&#x3D;014&amp;aid&#x3D;0005474452" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">8</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/008/0005314942" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005314942" data-imp-url="https://n.news.naver.com/mnews/article/008/0005314942" data-imp-index="6">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/008/2026/02/06/5314942.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/008/0005314942" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005314942" data-imp-url="https://n.news.naver.com/mnews/article/008/0005314942" data-imp-index="6">
# 							<strong class="sa_text_strong">네이버, 지난해 매출 12조 &#x27;역대 최대&#x27;…&quot;커머스 효과&quot;</strong>
# 						</a>
# 						<div class="sa_text_lede">네이버(NAVER)가 지난해 4분기 매출 3조1951억원, 영업이익 6106억원을 기록했다고 6일 밝혔다. 매출은 전년 동기 대비 10.7%, 영업이익은 12.7% 증가했다. 지난해 연간 매출액은 전년 대비 12.1</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">머니투데이</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/008/0005314942" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news008,0005314942" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602060810_00000001/section/105?oid&#x3D;008&amp;aid&#x3D;0005314942" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">29</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/056/0012120262" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="88000114_000000000000000012120262" data-imp-url="https://n.news.naver.com/mnews/article/056/0012120262" data-imp-index="7">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/056/2026/02/06/12120262.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/056/0012120262" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="88000114_000000000000000012120262" data-imp-url="https://n.news.naver.com/mnews/article/056/0012120262" data-imp-index="7">
# 							<strong class="sa_text_strong">구글, 정부에 ‘고정밀 지도’ 반출 관련 서류 제출</strong>
# 						</a>
# 						<div class="sa_text_lede">구글이 정부가 요구한 고정밀 지도 국외 반출 관련 추가 서류를 제출했습니다. 국토교통부는 구글이 어제(5일) 밤 11시쯤 고정밀 지도 반출을 요청하는 내용의 보완 서류를 제출했다고 밝혔습니다. 정부는 구글이 제출한</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">KBS</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/056/0012120262" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news056,0012120262" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602031530_00000077/section/105?oid&#x3D;056&amp;aid&#x3D;0012120262" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">27</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 		<li class="sa_item _SECTION_HEADLINE is_blind">
# 			<div class="sa_item_inner">
# 				<div class="sa_item_flex _LAZY_LOADING_WRAP">
# 					<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# 						<div class="sa_thumb_inner">
# 							<a href="https://n.news.naver.com/mnews/article/008/0005315024" class="sa_thumb_link _NLOG_IMPRESSION" tabIndex="-1" aria-hidden="true" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005315024" data-imp-url="https://n.news.naver.com/mnews/article/008/0005315024" data-imp-index="8">
# 								<img data-src="https://mimgnews.pstatic.net/image/origin/008/2026/02/06/5315024.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="" style="display: none;">
# 							</a>
# 						</div>
# 					</div>
# 					<div class="sa_text">
# 						<a href="https://n.news.naver.com/mnews/article/008/0005315024" class="sa_text_title _NLOG_IMPRESSION" data-clk="itn.clart" data-imp-gdid="880000C2_000000000000000005315024" data-imp-url="https://n.news.naver.com/mnews/article/008/0005315024" data-imp-index="8">
# 							<strong class="sa_text_strong">&quot;결과 없어도 인정&quot; 한컴, 전사 AI 학습 조직 &#x27;아이디어 크루&#x27; 출범</strong>
# 						</a>
# 						<div class="sa_text_lede">한글과컴퓨터가 임직원들의 자발적 AI 역량 강화를 위해 전사 학습 조직을 꾸린다. 결과물보다 과정 공유를 중시하는 방식으로 &#x27;즐기는 AI 문화&#x27; 정착에 나섰다. 6일 한글과컴퓨터에 따르면 회사는 프로젝트형 학습 조직</div>
# 						<div class="sa_text_info">
# 							<div class="sa_text_info_left">
# 								<div class="sa_text_press">머니투데이</div>
# 								<a href="https://n.news.naver.com/mnews/article/comment/008/0005315024" class="sa_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news008,0005315024" data-zero-allow="false"></a>
# 							</div>
# 							<div class="sa_text_info_right">
# 								<a href="/cluster/c_202602060940_00000018/section/105?oid&#x3D;008&amp;aid&#x3D;0005315024" class="sa_text_cluster" data-clk="clcou">
# 									<span class="sa_text_cluster_num">8</span>
# 									<span class="blind">개의 관련뉴스 더보기</span>
# 								</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</li>
# 	</ul>
# </div>
# <div class="section_more _SECTION_HEADLINE_MORE_BUTTON_WRAP">
# 	<a href="#" class="section_more_inner _SECTION_HEADLINE_MORE_BUTTON _NLOG_IMPRESSION_TRIGGER" data-target="_SECTION_HEADLINE_LIST_9ktjb" data-clk="clsmore">헤드라인 더보기</a>
# </div>
# </div>
# <div class="section_component as_section_series _PERSIST_CONTENT" data-persist="3_sectionSeries">
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# 	<div class="ss_head">
# 		<div class="ss_head_inner">
# 			<a href="https://news.naver.com/hotissue/main?sid1&#x3D;163&amp;cid&#x3D;1089789" class="ss_head_link" data-clk="sert">
# 				<span class="ss_head_go">연재보기</span>
# 				<h2 class="ss_head_topic">배터리레이다</h2>
# 			</a>
# 		</div>
# 	</div>
# 	<div class="ss_body">
# 		<ul class="ss_list">
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217337?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217337" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217337?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="stt5b">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2026/02/06/2217337.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="비중국 전기차 배터리 26% 성장에도… 한국 3사 점유율 36%로 후퇴" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217337?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217337" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217337?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="stt5b">비중국 전기차 배터리 26% 성장에도… 한국 3사 점유율 36%로 후퇴</a>
# 					<div class="ss_text_lede">2025년 한 해 중국을 제외한 글로벌 전기차용 배터리 시장이 두 자릿수 성장세를 이어갔지만 국내 배터리 3사의 시장 점유율은 오히려 하락한 것으로 나타났다. 비중국 시장에서도 중국계 배터리 업체들의 영향력이 빠르게</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002217337" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002217337" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217273?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217273" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217273?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="hu8hy">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2026/02/05/2217273.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="엘앤에프, 테슬라·46파이 출하 효과에 &#x27;깜짝 실적&#x27;" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217273?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217273" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217273?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="hu8hy">엘앤에프, 테슬라·46파이 출하 효과에 &#x27;깜짝 실적&#x27;</a>
# 					<div class="ss_text_lede">2025년 4분기 &#x27;어닝 서프라이즈&#x27;를 기록한 엘앤에프가 46파이 원통형 배터리, 올해 양산에 돌입할 에너지저장장치(ESS)용 리튬인산철(LFP) 배터리 양극재로 판도를 넓힌다. 기존 하이니켈 영역 내 공급 다변화와</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002217273" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002217273" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217257?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217257" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217257?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="nr48y">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2026/02/05/2217257.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="에코프로, 작년 영업이익 2332억원 &#x27;흑자전환&#x27;…인니⋅메탈·유럽, 성장 견인" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217257?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217257" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217257?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="nr48y">에코프로, 작년 영업이익 2332억원 &#x27;흑자전환&#x27;…인니⋅메탈·유럽, 성장 견인</a>
# 					<div class="ss_text_lede">에코프로가 인도네시아 제련 투자 성과와 메탈 가격 상승 효과를 앞세워 지난해 연간 흑자전환에 성공했다. 전기차 수요 둔화가 이어지는 상황에서도 원가 경쟁력 강화와 사업 구조 다변화가 실적 개선으로 이어졌다는 평가다.</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002217257" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002217257" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217241?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217241" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217241?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="deguq">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/138/2026/02/05/2217241.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="&quot;북미 물량 감소 불가피&quot;…에코프로비엠, 유럽 &#x27;헝가리&#x27;로 빈자리 메운다" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/138/0002217241?type&#x3D;series&amp;cid&#x3D;1089789" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="880000AC_000000000000000002217241" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/138/0002217241?type&#x3D;series&amp;cid&#x3D;1089789" data-imp-index="deguq">&quot;북미 물량 감소 불가피&quot;…에코프로비엠, 유럽 &#x27;헝가리&#x27;로 빈자리 메운다</a>
# 					<div class="ss_text_lede">&quot;포드를 포함한 북미 전기차 물량은 감소가 불가피할 것으로 전망됩니다.&quot; 에코프로비엠이 5일 열린 2025년 4분기 실적 발표 컨퍼런스콜에서 북미 전방의 둔화를 정면으로 언급했다. SK온-포드 합작법인 종료와 포드 </div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">디지털데일리</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/138/0002217241" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news138,0002217241" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 		</ul>
# 	</div>
# </div>
# <div class="section_series _TEMPLATE" data-template-id="SECTION_SERIES">
# 	<div class="ss_head">
# 		<div class="ss_head_inner">
# 			<a href="https://news.naver.com/hotissue/main?sid1&#x3D;163&amp;cid&#x3D;1087940" class="ss_head_link" data-clk="sert">
# 				<span class="ss_head_go">연재보기</span>
# 				<h2 class="ss_head_topic">이슈진단+</h2>
# 			</a>
# 		</div>
# 	</div>
# 	<div class="ss_body">
# 		<ul class="ss_list">
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409487?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409487" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409487?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="q3lk1">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/092/2026/02/05/2409487.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="저평가 보안주들...상장사 절반 이상 지난 1년새 하락" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409487?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409487" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409487?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="q3lk1">저평가 보안주들...상장사 절반 이상 지난 1년새 하락</a>
# 					<div class="ss_text_lede">지난해 잇단 해킹 사고가 발생했음에도 주요 보안 상장사들의 절반 이상은 오히려 주가가 1년 새 하락한 것으로 나타났다. 특히 정치 테마주로 분류돼 지난해 초 주가가 급등했다가 큰 낙폭을 기록한 안랩, 수산아이앤티 등</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">ZDNet Korea</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/092/0002409487" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news092,0002409487" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409262?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409262" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409262?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="8g6gh">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/092/2026/02/04/2409262.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="작년 대형 해킹 잇달아...보안 기업들 1년간 주가 동향은?" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409262?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409262" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409262?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="8g6gh">작년 대형 해킹 잇달아...보안 기업들 1년간 주가 동향은?</a>
# 					<div class="ss_text_lede">코스피 지수가 역사상 처음으로 5000선을 돌파하면서 한국 증시가 강세장(bull market)에 진입했다는 평가다. 작년 국내 보안 시장은 잇달은 대형 해킹 사건으로 몸살을 앓았다. 기업과 기관에 해킹을 막는 솔루</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">ZDNet Korea</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/092/0002409262" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news092,0002409262" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409153?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409153" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409153?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="ojdxb">
# 							<img data-src="https://mimgnews.pstatic.net/image/origin/092/2026/02/04/2409153.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="생성형 AI 패러다임 바뀔까…구글 &#x27;지니&#x27; 공개에 산업계 지형 변화 예고" style="display:none;">
# 						</a>
# 					</div>
# 				</div>
# 				<div class="ss_text">
# 					<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409153?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_text_headline _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409153" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409153?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="ojdxb">생성형 AI 패러다임 바뀔까…구글 &#x27;지니&#x27; 공개에 산업계 지형 변화 예고</a>
# 					<div class="ss_text_lede">구글 딥마인드가 AI 프로젝트 &#x27;지니(Genie)&#x27;를 공개했습니다. 지니는 텍스트 프롬프트 등을 활용해 가상 환경을 구현할 수 있는 차세대 생성형AI 모델로 요약됩니다. 아직 프로토타입 단계지만, 게임·영화·애니메이</div>
# 					<div class="ss_text_info">
# 						<div class="ss_text_press">ZDNet Korea</div>
# 						<a href="https://n.news.naver.com/mnews/article/comment/092/0002409153" class="ss_text_cmt _COMMENT_COUNT_LIST" style="display: none;" data-ticket="news" data-object-id="news092,0002409153" data-zero-allow="false" data-clk="sercmtcount"></a>
# 					</div>
# 				</div>
# 			</li>
# 			<li class="ss_item _LAZY_LOADING_WRAP">
# 				<div class="ss_thumb _LAZY_LOADING_ERROR_HIDE">
# 					<div class="ss_thumb_inner">
# 						<a href="https://n.news.naver.com/mnews/hotissue/article/092/0002409152?type&#x3D;series&amp;cid&#x3D;1087940" class="ss_thumb_link _NLOG_IMPRESSION" data-clk="itn.sera" data-imp-gdid="8800011E_000000000000000002409152" data-imp-url="https://n.news.naver.com/mnews/hotissue/article/092/0002409152?type&#x3D;series&amp;cid&#x3D;1087940" data-imp-index="rgdq0">
# ...
# 			{{/journalist}}
# </script>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION" class="modal is_hidden"></div>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION_ALL" class="modal is_hidden"></div>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION_OS" class="modal is_hidden"></div>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 구독이 완료되었습니다. <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">아니오</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">예</button>
# 	</div>
# </div>
# </script>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 구독이 완료되었습니다. <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">아니오</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">예</button>
# 	</div>
# </div>
# </script>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_DIALOG_WRAP" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_MODAL_DIALOG_TEMPLATE">
# <div class="nds_dialog_dimmed">
# 	<div class="nds_dialog_basic">
# 		<div class="nds_dialog_content">
# 			{{#content.image}}
# 			<div class="nds_dialog_image_area">
# 				{{#content.image.class}}
# 				<i class="nds_dialog_image_icon {{content.image.class}}"></i>
# 				{{/content.image.class}}
# 			</div>
# 			{{/content.image}}
# 			{{#isTextType}}
# 			<p class="nds_dialog_text">{{content.title}}</p>
# 			{{/isTextType}}
# 			{{#isTitleType}}
# 			<strong class="nds_dialog_title">
# 				<span class="nds_dialog_title_ellipsis">{{content.headTitle}}</span>
# 				{{content.title}}
# 			</strong>
# 			<p class="nds_dialog_description">{{content.description}}</p>
# 			{{/isTitleType}}
# 		</div>
# 		<div class="nds_dialog_button_area">
# 			<div class="nds_button_main_action as_layout_5_5">
# 				{{#isCancel}}
# 				<button type="button" class="nds_button_wide _MODAL_CANCEL"{{#content.clk.cancelClk}} data-clk="{{content.clk.cancelClk}}"{{/content.clk.cancelClk}}>
# 				{{content.cancelMessage}}
# 				</button>
# 				{{/isCancel}}
# 				<button type="button" class="nds_button_wide as_{{buttonStyleType}} _MODAL_CONFIRM"{{#content.clk.confirmClk}} data-clk="{{content.clk.confirmClk}}"{{/content.clk.confirmClk}}>
# 				{{content.confirmMessage}}
# 				</button>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_TOAST" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_MODAL_TOAST_TEMPLATE">
# <div class="nds_popover_toast as_center">
# 	<div class="nds_toast_text_area">
# 		<div class="nds_toast_text_area"><span class="nds_toast_ellipsis_text"><strong>{{toastTitle}}</strong></span> {{toastMessage}}</div>
# 	</div>
# </div>
# </script>
# <div id="_TICKER_LAYER_FOR_NOTIFICATION" class="ticker" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.{{#isSupportedNaverappNotificationSetting}} 네이버앱 전체 푸시 알림도 활성화된 상태입니다.{{/isSupportedNaverappNotificationSetting}}</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20260205/library.min.js" crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20260205/read.min.js" crossorigin="anonymous" onerror="neloSender.sendErrorToNelo('스크립트 로딩 에러 : ' + this.src);"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"105","name":"IT"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					window.impression.sendImpressionNlog([], "disable");
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					window.impression.sendImpressionNlog([], "disable");
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					window.impression.sendImpressionNlog([], "disable");
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# 		</div>
# 		<script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService",
# 					nlogEvt: {
# 						page_layout: window.layoutName,
# 						news: window.getNLogNewsData()
# 					}
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "105"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
#
# 				setTimeout(function() {
# 					$("._OPACITY_FADE_TO").fadeTo(50, 1);
# 				}, 3000);
# 			});
# 		</script>
# 	</body>
# </html>
#
# 실적 새 역사 쓴 넷마블…‘다장르 신작’ 전략 통했다
# https://n.news.naver.com/mnews/article/011/0004587151
#
# https://n.news.naver.com/mnews/article/comment/011/0004587151
# AI로 해킹 파장 줄인 통신사… 데이터센터 등 수익성 높인다
# https://n.news.naver.com/mnews/article/014/0005474274
#
# https://n.news.naver.com/mnews/article/comment/014/0005474274
# 오픈AI, 차세대 에이전트형 코딩 모델 ‘GPT-5.3-코덱스’ 공개
# https://n.news.naver.com/mnews/article/138/0002217304
#
# https://n.news.naver.com/mnews/article/comment/138/0002217304
# 천하람 "술에 취해 여학우 성희롱, 일어날 수 있는 일" 과거 글 논란
# https://n.news.naver.com/mnews/article/469/0000912947
#
# https://n.news.naver.com/mnews/article/comment/469/0000912947
# 네이버, 'N배송' 3년내 50% 이상 확대...멤버십 목표도 20%↑[컨콜]
# https://n.news.naver.com/mnews/article/014/0005474452
#
# https://n.news.naver.com/mnews/article/comment/014/0005474452
# 네이버, 지난해 매출 12조 '역대 최대'…"커머스 효과"
# https://n.news.naver.com/mnews/article/008/0005314942
#
# https://n.news.naver.com/mnews/article/comment/008/0005314942
# 구글, 정부에 ‘고정밀 지도’ 반출 관련 서류 제출
# https://n.news.naver.com/mnews/article/056/0012120262
#
# https://n.news.naver.com/mnews/article/comment/056/0012120262
# "결과 없어도 인정" 한컴, 전사 AI 학습 조직 '아이디어 크루' 출범
# https://n.news.naver.com/mnews/article/008/0005315024
#
# https://n.news.naver.com/mnews/article/comment/008/0005315024
# 50년 전 등장한 ‘똥 알약’, 이번엔 암 치료에 쓰인다
# https://n.news.naver.com/mnews/article/009/0005633427
#
# https://n.news.naver.com/mnews/article/comment/009/0005633427
# 추락하는 비트코인…"디지털 금 맞나요?"
# https://n.news.naver.com/mnews/article/092/0002409536
#
# https://n.news.naver.com/mnews/article/comment/092/0002409536
# [AI는 지금] 오픈AI·앤트로픽, 코딩 AI 정면승부…SW 재편 우려에 美 증시도 '흔들'
# https://n.news.naver.com/mnews/article/092/0002409535
#
# https://n.news.naver.com/mnews/article/comment/092/0002409535
# 美 외교·안보 고문 "쿠팡 규제, SKT 사고 때 보다 더 가혹"
# https://n.news.naver.com/mnews/article/092/0002409533
#
# https://n.news.naver.com/mnews/article/comment/092/0002409533
# 비중국 전기차 배터리 26% 성장에도… 한국 3사 점유율 36%로 후퇴 [배터리레이다]
# https://n.news.naver.com/mnews/article/138/0002217337
#
# https://n.news.naver.com/mnews/article/comment/138/0002217337
# “年7000조원을 쏟아부을 수 있다고?” 회의론 쏟아지는 머스크 ‘야심작’ 뭐길래?
# https://n.news.naver.com/mnews/article/016/0002596947
#
# https://n.news.naver.com/mnews/article/comment/016/0002596947
# "국가대표 AI 탈락, 네이버 기술력 방증 아냐"[컨콜]
# https://n.news.naver.com/mnews/article/018/0006214555
#
# https://n.news.naver.com/mnews/article/comment/018/0006214555
# 사상 첫 연간 매출 12조원 돌파…네이버 최수연 “검색 넘어 에이전틱 AI로 수익성 강화”
# https://n.news.naver.com/mnews/article/016/0002596941
#
# https://n.news.naver.com/mnews/article/comment/016/0002596941
# 中, 100km 거리서 '해킹 불가' 고난도 양자암호통신 성공
# https://n.news.naver.com/mnews/article/584/0000036311
#
# https://n.news.naver.com/mnews/article/comment/584/0000036311
# 롯데쇼핑, 작년 영업익 5470억원...마트는 적자전환
# https://n.news.naver.com/mnews/article/092/0002409520
#
# https://n.news.naver.com/mnews/article/comment/092/0002409520
# 머리에 칩 심은 살아있는 드론…러 ‘사이보그 비둘기’ 개발 [핵잼 사이언스]
# https://n.news.naver.com/mnews/article/081/0003615186
#
# https://n.news.naver.com/mnews/article/comment/081/0003615186
# 털리고 털렸는데 또…쿠팡 추가유출 소식에 불안은 '고객 몫'
# https://n.news.naver.com/mnews/article/138/0002217317
#
# https://n.news.naver.com/mnews/article/comment/138/0002217317
# 구글, 정부에 지도반출 보완서류 제출…최종 결정 수개월 걸릴듯
# https://n.news.naver.com/mnews/article/277/0005717947
#
# https://n.news.naver.com/mnews/article/comment/277/0005717947
# AWS, 4분기 매출 356억 달러…AI 훈풍 타고 24% '급성장'
# https://n.news.naver.com/mnews/article/092/0002409513
#
# https://n.news.naver.com/mnews/article/comment/092/0002409513
# 50년 만에 재정의 된 목성…크기 조금 더 작고, 20배 납작하다
# https://n.news.naver.com/mnews/article/028/0002790291
#
# https://n.news.naver.com/mnews/article/comment/028/0002790291
# 조직개편, 인사 줄줄이 지연…KT ‘시계제로’
# https://n.news.naver.com/mnews/article/016/0002596887
#
# https://n.news.naver.com/mnews/article/comment/016/0002596887
# 주요 PC 제조사, 메모리 수급난 속 중국산 D램 수급 검토
# https://n.news.naver.com/mnews/article/092/0002409508
#
# https://n.news.naver.com/mnews/article/comment/092/0002409508
# 2시간 대기는 기본이라는 ‘웨이팅 맛집’…당신은 속고 있었다
# https://n.news.naver.com/mnews/article/009/0005633331
#
# https://n.news.naver.com/mnews/article/comment/009/0005633331
# AI발 구리 쟁탈전 속 ‘광산 빅딜’ 무산…리오틴토-글렌코어 결별
# https://n.news.naver.com/mnews/article/092/0002409505
#
# https://n.news.naver.com/mnews/article/comment/092/0002409505
# SKB, 초고속·IPTV 신규 고객 ‘출동비 무료’ 등 혜택
# https://n.news.naver.com/mnews/article/016/0002596875
#
# https://n.news.naver.com/mnews/article/comment/016/0002596875
# 어른이 맞는 21가 폐렴구균 백신 '캡박시브' "넓은 혈청형이 매력"
# https://n.news.naver.com/mnews/article/014/0005474424
#
# https://n.news.naver.com/mnews/article/comment/014/0005474424
# AWS, 24% 성장에도 주가 10% 급락…2000억 달러 AI 투자 부담 [클라우드+]
# https://n.news.naver.com/mnews/article/031/0001003515
#
# https://n.news.naver.com/mnews/article/comment/031/0001003515
# 비트코인, 1억원 밑으로 추락...고점 대비 절반 수준
# https://n.news.naver.com/mnews/article/092/0002409503
#
# https://n.news.naver.com/mnews/article/comment/092/0002409503
# SKB, AI 5 셋톱·기가와이파이7 신규 가입자는 출동비 무료
# https://n.news.naver.com/mnews/article/003/0013752910
#
# https://n.news.naver.com/mnews/article/comment/003/0013752910
# “보급형 중 역대 최고” 애플, 아이폰17e 2월 19일 공개 유력[모닝폰]
# https://n.news.naver.com/mnews/article/018/0006214457
#
# https://n.news.naver.com/mnews/article/comment/018/0006214457
# AI에 밀린 지포스..."엔비디아, RTX 50 GPU 추가 출시 보류"
# https://n.news.naver.com/mnews/article/092/0002409498
#
# https://n.news.naver.com/mnews/article/comment/092/0002409498
# "아이폰17e, 노치 그대로 유지…19일 공개 유력"
# https://n.news.naver.com/mnews/article/092/0002409496
#
# https://n.news.naver.com/mnews/article/comment/092/0002409496
# 공기업 해외광물개발 ‘10년만에’ 허용… hy, 하이브와 합작법인 설립 [스타트업 뉴스]
# https://n.news.naver.com/mnews/article/011/0004587416
#
# https://n.news.naver.com/mnews/article/comment/011/0004587416
# 우주·동물약·M&A…제약업계 '오너 3세' 신사업 실험 한창
# https://n.news.naver.com/mnews/article/018/0006214399
#
# https://n.news.naver.com/mnews/article/comment/018/0006214399
# 이수앱지스 “신약 ‘빅딜’ 목표…희귀藥 매출은 중장기 성장 뒷받침”
# https://n.news.naver.com/mnews/article/018/0006214360
#
# https://n.news.naver.com/mnews/article/comment/018/0006214360
# 안면인증 전면 도입했지만…알뜰폰 비대면 개통 '막막'
# https://n.news.naver.com/mnews/article/648/0000044283
#
# https://n.news.naver.com/mnews/article/comment/648/0000044283
# 아마존 "올해 293조원 투자"...주가 10% 급락
# https://n.news.naver.com/mnews/article/215/0001240781
#
# https://n.news.naver.com/mnews/article/comment/215/0001240781
# 레벨4 자율주행 눈앞…라이드플럭스, ‘완전 무인’ 실증 신청
# https://n.news.naver.com/mnews/article/011/0004587385
#
# https://n.news.naver.com/mnews/article/comment/011/0004587385
# 배터리 안전 ‘소량의 물질’이 좌우한다
# https://n.news.naver.com/mnews/article/011/0004587384
#
# https://n.news.naver.com/mnews/article/comment/011/0004587384
# [언박싱 연구실] 산소 없어도 OK! '물'로 암세포 터뜨리는 빛의 마법
# https://n.news.naver.com/mnews/article/014/0005474373
#
# https://n.news.naver.com/mnews/article/comment/014/0005474373
# 영업익 40% 줄었는데 주가는 천장…SK텔레콤의 '반전' 이유 [테크로그]
# https://n.news.naver.com/mnews/article/015/0005247675
#
# https://n.news.naver.com/mnews/article/comment/015/0005247675

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {
    '정치': 100, 
    '경제': 101, 
    '사회': 102, 
    '생활/문화': 103, 
    '세계': 104, 
    'IT/과학': 105
}

def print_news(section_name):  #print_new(103,'생활/문화') 
    sid = section_dict.get(section_name,'정치')
    url = f'http://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 / {url}')
    req_header = {
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}
    # requests 의 get() 함수 호출하기 
res  = requests.get(url, headers=req_header)
if res.ok:
    soup = BeautifulSoup(res.text,'html.parser')
    print(len(soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")))
    # CSS 선택자를 사용해서 a tag 목록 가져오기
    a_tags = soup.select("div.sa_text a[href^='https://n.news.naver.com/mnews/']")
    for a_tag in a_tags:
        title = (a_tag.text.strip())
        link = a_tag['href']
        print(title)
        print(link)

else:
    # 응답(response)이 error이면 status_code 출력
    print(f'Error Code = {res.status_code}')
# Out:
# 88
# 네이버 지난해 매출 12조·영업익 2조 돌파… '역대 최대 실적'
# https://n.news.naver.com/mnews/article/417/0001128585
#
# https://n.news.naver.com/mnews/article/comment/417/0001128585
# 구글, 정부에 ‘고정밀 지도’ 반출 관련 서류 제출
# https://n.news.naver.com/mnews/article/056/0012120262
#
# https://n.news.naver.com/mnews/article/comment/056/0012120262
# “고대생 다 욕구불만 변태 아냐” 천하람…네이버 오류에 ‘지식인’ 노출 사고
# https://n.news.naver.com/mnews/article/022/0004103477
#
# https://n.news.naver.com/mnews/article/comment/022/0004103477
# LG유플러스 "올해 CAPEX, AIDC·보안 중심"[컨콜]
# https://n.news.naver.com/mnews/article/119/0003056349
#
# https://n.news.naver.com/mnews/article/comment/119/0003056349
# 네이버 "엔비디아와 로봇 관련 협업⋯엔비디아 옴니버스 플랫폼 활용"[컨콜]
# https://n.news.naver.com/mnews/article/031/0001003574
#
# https://n.news.naver.com/mnews/article/comment/031/0001003574
# 휴네시온, 작년 매출 377억·영업익 48억…사상 최대 실적
# https://n.news.naver.com/mnews/article/003/0013752851
#
# https://n.news.naver.com/mnews/article/comment/003/0013752851
# 네이버 "올해 멤버십 활성 이용자 20% 이상 성장 목표"[컨콜]
# https://n.news.naver.com/mnews/article/031/0001003551
#
# https://n.news.naver.com/mnews/article/comment/031/0001003551
# 데브시스터즈 "확장·진화 원년"…쿠키런 멀티유니버스 본격 가동
# https://n.news.naver.com/mnews/article/008/0005315030
#
# https://n.news.naver.com/mnews/article/comment/008/0005315030
# 50년 전 등장한 ‘똥 알약’, 이번엔 암 치료에 쓰인다
# https://n.news.naver.com/mnews/article/009/0005633427
#
# https://n.news.naver.com/mnews/article/comment/009/0005633427
# 추락하는 비트코인…"디지털 금 맞나요?"
# https://n.news.naver.com/mnews/article/092/0002409536
#
# https://n.news.naver.com/mnews/article/comment/092/0002409536
# [AI는 지금] 오픈AI·앤트로픽, 코딩 AI 정면승부…SW 재편 우려에 美 증시도 '흔들'
# https://n.news.naver.com/mnews/article/092/0002409535
#
# https://n.news.naver.com/mnews/article/comment/092/0002409535
# 美 외교·안보 고문 "쿠팡 규제, SKT 사고 때 보다 더 가혹"
# https://n.news.naver.com/mnews/article/092/0002409533
#
# https://n.news.naver.com/mnews/article/comment/092/0002409533
# 비중국 전기차 배터리 26% 성장에도… 한국 3사 점유율 36%로 후퇴 [배터리레이다]
# https://n.news.naver.com/mnews/article/138/0002217337
#
# https://n.news.naver.com/mnews/article/comment/138/0002217337
# “年7000조원을 쏟아부을 수 있다고?” 회의론 쏟아지는 머스크 ‘야심작’ 뭐길래?
# https://n.news.naver.com/mnews/article/016/0002596947
#
# https://n.news.naver.com/mnews/article/comment/016/0002596947
# "국가대표 AI 탈락, 네이버 기술력 방증 아냐"[컨콜]
# https://n.news.naver.com/mnews/article/018/0006214555
#
# https://n.news.naver.com/mnews/article/comment/018/0006214555
# 사상 첫 연간 매출 12조원 돌파…네이버 최수연 “검색 넘어 에이전틱 AI로 수익성 강화”
# https://n.news.naver.com/mnews/article/016/0002596941
#
# https://n.news.naver.com/mnews/article/comment/016/0002596941
# 中, 100km 거리서 '해킹 불가' 고난도 양자암호통신 성공
# https://n.news.naver.com/mnews/article/584/0000036311
#
# https://n.news.naver.com/mnews/article/comment/584/0000036311
# 롯데쇼핑, 작년 영업익 5470억원...마트는 적자전환
# https://n.news.naver.com/mnews/article/092/0002409520
#
# https://n.news.naver.com/mnews/article/comment/092/0002409520
# 머리에 칩 심은 살아있는 드론…러 ‘사이보그 비둘기’ 개발 [핵잼 사이언스]
# https://n.news.naver.com/mnews/article/081/0003615186
#
# https://n.news.naver.com/mnews/article/comment/081/0003615186
# 털리고 털렸는데 또…쿠팡 추가유출 소식에 불안은 '고객 몫'
# https://n.news.naver.com/mnews/article/138/0002217317
#
# https://n.news.naver.com/mnews/article/comment/138/0002217317
# 구글, 정부에 지도반출 보완서류 제출…최종 결정 수개월 걸릴듯
# https://n.news.naver.com/mnews/article/277/0005717947
#
# https://n.news.naver.com/mnews/article/comment/277/0005717947
# AWS, 4분기 매출 356억 달러…AI 훈풍 타고 24% '급성장'
# https://n.news.naver.com/mnews/article/092/0002409513
#
# https://n.news.naver.com/mnews/article/comment/092/0002409513
# 50년 만에 재정의 된 목성…크기 조금 더 작고, 20배 납작하다
# https://n.news.naver.com/mnews/article/028/0002790291
#
# https://n.news.naver.com/mnews/article/comment/028/0002790291
# 조직개편, 인사 줄줄이 지연…KT ‘시계제로’
# https://n.news.naver.com/mnews/article/016/0002596887
#
# https://n.news.naver.com/mnews/article/comment/016/0002596887
# 주요 PC 제조사, 메모리 수급난 속 중국산 D램 수급 검토
# https://n.news.naver.com/mnews/article/092/0002409508
#
# https://n.news.naver.com/mnews/article/comment/092/0002409508
# 2시간 대기는 기본이라는 ‘웨이팅 맛집’…당신은 속고 있었다
# https://n.news.naver.com/mnews/article/009/0005633331
#
# https://n.news.naver.com/mnews/article/comment/009/0005633331
# AI발 구리 쟁탈전 속 ‘광산 빅딜’ 무산…리오틴토-글렌코어 결별
# https://n.news.naver.com/mnews/article/092/0002409505
#
# https://n.news.naver.com/mnews/article/comment/092/0002409505
# SKB, 초고속·IPTV 신규 고객 ‘출동비 무료’ 등 혜택
# https://n.news.naver.com/mnews/article/016/0002596875
#
# https://n.news.naver.com/mnews/article/comment/016/0002596875
# 어른이 맞는 21가 폐렴구균 백신 '캡박시브' "넓은 혈청형이 매력"
# https://n.news.naver.com/mnews/article/014/0005474424
#
# https://n.news.naver.com/mnews/article/comment/014/0005474424
# AWS, 24% 성장에도 주가 10% 급락…2000억 달러 AI 투자 부담 [클라우드+]
# https://n.news.naver.com/mnews/article/031/0001003515
#
# https://n.news.naver.com/mnews/article/comment/031/0001003515
# 비트코인, 1억원 밑으로 추락...고점 대비 절반 수준
# https://n.news.naver.com/mnews/article/092/0002409503
#
# https://n.news.naver.com/mnews/article/comment/092/0002409503
# SKB, AI 5 셋톱·기가와이파이7 신규 가입자는 출동비 무료
# https://n.news.naver.com/mnews/article/003/0013752910
#
# https://n.news.naver.com/mnews/article/comment/003/0013752910
# “보급형 중 역대 최고” 애플, 아이폰17e 2월 19일 공개 유력[모닝폰]
# https://n.news.naver.com/mnews/article/018/0006214457
#
# https://n.news.naver.com/mnews/article/comment/018/0006214457
# AI에 밀린 지포스..."엔비디아, RTX 50 GPU 추가 출시 보류"
# https://n.news.naver.com/mnews/article/092/0002409498
#
# https://n.news.naver.com/mnews/article/comment/092/0002409498
# "아이폰17e, 노치 그대로 유지…19일 공개 유력"
# https://n.news.naver.com/mnews/article/092/0002409496
#
# https://n.news.naver.com/mnews/article/comment/092/0002409496
# 공기업 해외광물개발 ‘10년만에’ 허용… hy, 하이브와 합작법인 설립 [스타트업 뉴스]
# https://n.news.naver.com/mnews/article/011/0004587416
#
# https://n.news.naver.com/mnews/article/comment/011/0004587416
# 우주·동물약·M&A…제약업계 '오너 3세' 신사업 실험 한창
# https://n.news.naver.com/mnews/article/018/0006214399
#
# https://n.news.naver.com/mnews/article/comment/018/0006214399
# 이수앱지스 “신약 ‘빅딜’ 목표…희귀藥 매출은 중장기 성장 뒷받침”
# https://n.news.naver.com/mnews/article/018/0006214360
#
# https://n.news.naver.com/mnews/article/comment/018/0006214360
# 안면인증 전면 도입했지만…알뜰폰 비대면 개통 '막막'
# https://n.news.naver.com/mnews/article/648/0000044283
#
# https://n.news.naver.com/mnews/article/comment/648/0000044283
# 아마존 "올해 293조원 투자"...주가 10% 급락
# https://n.news.naver.com/mnews/article/215/0001240781
#
# https://n.news.naver.com/mnews/article/comment/215/0001240781
# 레벨4 자율주행 눈앞…라이드플럭스, ‘완전 무인’ 실증 신청
# https://n.news.naver.com/mnews/article/011/0004587385
#
# https://n.news.naver.com/mnews/article/comment/011/0004587385
# 배터리 안전 ‘소량의 물질’이 좌우한다
# https://n.news.naver.com/mnews/article/011/0004587384
#
# https://n.news.naver.com/mnews/article/comment/011/0004587384
# [언박싱 연구실] 산소 없어도 OK! '물'로 암세포 터뜨리는 빛의 마법
# https://n.news.naver.com/mnews/article/014/0005474373
#
# https://n.news.naver.com/mnews/article/comment/014/0005474373
# 영업익 40% 줄었는데 주가는 천장…SK텔레콤의 '반전' 이유 [테크로그]
# https://n.news.naver.com/mnews/article/015/0005247675
#
# https://n.news.naver.com/mnews/article/comment/015/0005247675

# %%
print_news('경제')
# Out:
# 101
# 경제 뉴스 / http://news.naver.com/section/101

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun',
    'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)
    # binary 응답 데이터 가져오기
    img_data = res.content   
    # url에서 파일명만 추출하기
    file_name = os.path.basename(img_url)  
    print(file_name)  
    # binday data를 file에 write하기
    with open(file_name, 'wb') as file:
        print(f'Writing to {file_name}({len(img_data):,} bytes)')
        file.write(img_data)
# Out:
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# 200
# 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = "https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun"

req_header = {
    "referer": webtoon_url,
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36",
}

res = requests.get(webtoon_url, headers=req_header)

if res.ok:
    # .jpg 파일명을 추출해서 list에 저장하기
    img_url_list = []
    soup = BeautifulSoup(res.text, "html.parser")
    img_tags = soup.select("img[src*='IMAG01']")
    for img_tag in img_tags:
        img_url = img_tag["src"]
        img_url_list.append(img_url)

    img_url_list2 = [img_tag["src"] for img_tag in img_tags]
    print(img_url_list2[:2])

    imgdir_name = "img"
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for img_url in img_url_list2:
        # requests 의 get(url, headers) 함수 호출하기
        res = requests.get(img_url, headers=req_header)
        # binary 응답 데이터 가져오기
        img_data = res.content
        # url에서 파일명만 추출하기
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        
        # binday data를 file에 write하기
        with open(file_path, "wb") as file:
            print(f"Writing to {file_path}({len(img_data):,} bytes)")
            file.write(img_data)

else:
    # 응답(response)이 error이면 status_code 출력
    print(f"Error Code = {res.status_code}")
# Out:
# ['https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg']
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_4.jpg(164,871 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_5.jpg(132,142 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_6.jpg(131,414 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_7.jpg(116,752 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_8.jpg(143,277 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_9.jpg(130,356 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_10.jpg(129,764 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_11.jpg(111,785 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_12.jpg(86,540 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_13.jpg(7,315 bytes)

# %% [markdown]
# ## 리팩토링된 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')
# Out:
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_1.jpg (164,266 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_2.jpg (119,906 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_3.jpg (130,933 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_4.jpg (130,725 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_5.jpg (134,506 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_6.jpg (166,312 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_7.jpg (135,069 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_8.jpg (95,346 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_9.jpg (160,655 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_10.jpg (157,106 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_11.jpg (159,141 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_12.jpg (94,296 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_13.jpg (91,062 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_14.jpg (2,915 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1' : open('img/f1.jpg','rb'),
    'img2' : open('img/f2.jpg','rb')
}
print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url, files=upload_files)
print(res.status_code)
print(res.json()['files']['img1'])
# Out:
# {'img1': <_io.BufferedReader name='img/f1.jpg'>, 'img2': <_io.BufferedReader name='img/f2.jpg'>}
# 200
# data:application/octet-stream;base64,...

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])
# Out:
# qmSw
# T_yq

# %%
# 캡차 키 발급 요청
import os
import sys
import urllib.request

code = "0"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"key":"fOQBQnqcnfNrMYzM"}

# %%
# 캡차 이미지 요청
import urllib.request

key = "fOQBQnqcnfNrMYzM" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# 캡차 이미지 저장

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
# 사용자 입력값 검증 요청
import requests
code = "1"
key = "fOQBQnqcnfNrMYzM"
value = "H257X1"
req_header = {
    "X-Naver-Client-Id" : CLIENT_ID,
    "X-Naver-Client-Secret" : CLIENT_SECRET
}
req_param = {
    "code" : code,
    "key" : key,
    "value" : value
}

url = "https://openapi.naver.com/v1/captcha/nkey"

#파이썬의 try...except 구문은 코드를 실행하다가 에러(예외)가 발생했을 때 프로그램이 갑자기 멈추지 않도록 방어막을 쳐주는 역할
try:
    res = requests.get(url, headers=req_header,params=req_param)
    #4xx, 5xx 오류가 발생하면 예외 발생시킴
    res.raise_for_status()
    print(res.text)
except requests.exceptions.RequestException as error:
    print(f'Status Code : {res.status_code}')
    # 네이버가 보내준 상세 에러 메시지 확인
    print(f'네이버 응답 상세: {res.text}')
    print(f'Error 발생 : {error}')

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import os
import sys
from pprint import pprint
import urllib.request
headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'
# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 
pprint(len(res.json()['items']))
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### json 파일 생성

# %%
#data/blog.json 파일 생성하기
import json
#한글 들어있어서 utf-8로 인코딩
with open('data/blog.json','w',encoding='utf-8') as file:
    json.dump(items_data,file)
